# %% [markdown]
# Lesson_2. Числові характеристики. Візуалізація.
# https://slogix.in/python-data-science-visualization-sample-of-source-code

# %%
#Завантажити Pandas

import pandas as pd
import numpy as np

# %% [markdown]
# Пакет Pandas має дві структури даних Series та DataFrame.

# %%
# можна зразу ввести і дані, і позначення для них
proba=pd.Series([10,23,23,34,45,56,67,45,89,90], ['a','b','c','d','вага','e','no','yes','r','or'])
proba
# Out:
# a       10
# b       23
# c       23
# d       34
# вага    45
# e       56
# no      67
# yes     45
# r       89
# or      90
# dtype: int64

# %%
#знайдемо основні числові характеристики
proba.describe()
# Out:
# count    10.00000
# mean     48.20000
# std      27.44206
# min      10.00000
# 25%      25.75000
# 50%      45.00000
# 75%      64.25000
# max      90.00000
# dtype: float64

# %%
#знайдемо моду
proba.mode()
# Out:
# 0    23
# 1    45
# dtype: int64

# %%
#знайдемо медіану
proba.median()
# Out:
# 45.0

# %%
#знайдемо коефіцієнти асиметрії та ексцесу
df=pd.DataFrame(proba)
print(df.skew())
# Out:
# 0    0.385726
# dtype: float64

# %%
print(df.kurtosis())
# Out:
# 0   -0.902816
# dtype: float64

# %%
# можна скласти варіаційний ряд
# sort the data:
data_sorted = np.sort(proba)
proba
# Out:
# a       10
# b       23
# c       23
# d       34
# вага    45
# e       56
# no      67
# yes     45
# r       89
# or      90
# dtype: int64

# %%
#завантажимо додаткові бібліотеки для гістограми і коробки з вусами
import matplotlib.pyplot as plot
import numpy as np

# %%
# будуємо і виводимо коробку з вусами
plot.boxplot(proba)
plot.show()

# %%
# будуємо гістограму
plot.hist(proba)
plot.show()
